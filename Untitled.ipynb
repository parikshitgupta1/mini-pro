# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib import rc

# %%
df_counties = pd.read_csv('us-counties.csv')

# %%
df_states = pd.read_csv('us-states.csv')

# %%
df_counties.head(10)
# Out:
#          date       county       state     fips  cases  deaths
# 0  2020-01-21    Snohomish  Washington  53061.0      1     0.0
# 1  2020-01-22    Snohomish  Washington  53061.0      1     0.0
# 2  2020-01-23    Snohomish  Washington  53061.0      1     0.0
# 3  2020-01-24         Cook    Illinois  17031.0      1     0.0
# 4  2020-01-24    Snohomish  Washington  53061.0      1     0.0
# 5  2020-01-25       Orange  California   6059.0      1     0.0
# 6  2020-01-25         Cook    Illinois  17031.0      1     0.0
# 7  2020-01-25    Snohomish  Washington  53061.0      1     0.0
# 8  2020-01-26     Maricopa     Arizona   4013.0      1     0.0
# 9  2020-01-26  Los Angeles  California   6037.0      1     0.0

# %%
df_counties.describe()
# Out:
#                 fips         cases         deaths
# count  934434.000000  9.432330e+05  923068.000000
# mean    31273.607788  2.256154e+03      57.562226
# std     16301.113750  1.185291e+04     462.654322
# min      1001.000000  0.000000e+00       0.000000
# 25%     19001.000000  4.100000e+01       0.000000
# 50%     29217.000000  2.690000e+02       5.000000
# 75%     46101.000000  1.161000e+03      25.000000
# max     78030.000000  1.024592e+06   26104.000000

# %%
ny_nassau = df_counties[(df_counties['state'] == 'New York') & (df_counties['county']=='Nassau')]

# %%
nassau_daily_cases = ny_nassau.cases.diff()
df_counties['Daily Cases'] = nassau_daily_cases

# %%
nassau_daily_deaths = ny_nassau.deaths.diff()
df_counties['Daily Deaths'] = nassau_daily_deaths

# %%
ny_nassau.head(10)
# Out:
#             date  county     state     fips  cases  deaths  Daily Cases  \
# 564   2020-03-05  Nassau  New York  36059.0      1     0.0          NaN
# 626   2020-03-06  Nassau  New York  36059.0      4     0.0          3.0
# 714   2020-03-07  Nassau  New York  36059.0      4     0.0          0.0
# 819   2020-03-08  Nassau  New York  36059.0      5     0.0          1.0
# 946   2020-03-09  Nassau  New York  36059.0     17     0.0         12.0
# 1097  2020-03-10  Nassau  New York  36059.0     19     0.0          2.0
# 1284  2020-03-11  Nassau  New York  36059.0     28     0.0          9.0
# 1520  2020-03-12  Nassau  New York  36059.0     41     0.0         13.0
# 1813  2020-03-13  Nassau  New York  36059.0     51     0.0         10.0
# 2162  2020-03-14  Nassau  New York  36059.0     79     0.0         28.0
#
#       Daily Deaths
# 564            NaN
# 626            0.0
# 714            0.0
# 819            0.0
# 946            0.0
# 1097           0.0
# 1284           0.0
# 1520           0.0
# 1813           0.0
# 2162           0.0

# %%
ny_nassau.tail(10)
# Out:
#               date  county     state     fips   cases  deaths  Daily Cases  \
# 912654  2021-01-09  Nassau  New York  36059.0  101181  2470.0       1742.0
# 915899  2021-01-10  Nassau  New York  36059.0  102584  2482.0       1403.0
# 919144  2021-01-11  Nassau  New York  36059.0  104078  2489.0       1494.0
# 922389  2021-01-12  Nassau  New York  36059.0  105497  2496.0       1419.0
# 925635  2021-01-13  Nassau  New York  36059.0  106954  2504.0       1457.0
# 928880  2021-01-14  Nassau  New York  36059.0  108126  2508.0       1172.0
# 932125  2021-01-15  Nassau  New York  36059.0  109984  2518.0       1858.0
# 935370  2021-01-16  Nassau  New York  36059.0  111393  2529.0       1409.0
# 938615  2021-01-17  Nassau  New York  36059.0  112702  2540.0       1309.0
# 941860  2021-01-18  Nassau  New York  36059.0  113812  2551.0       1110.0
#
#         Daily Deaths
# 912654           8.0
# 915899          12.0
# 919144           7.0
# 922389           7.0
# 925635           8.0
# 928880           4.0
# 932125          10.0
# 935370          11.0
# 938615          11.0
# 941860          11.0

# %%
ny_nassau['cases'].describe()
# Out:
# count       320.000000
# mean      45453.421875
# std       22047.929375
# min           1.000000
# 25%       39809.250000
# 50%       43742.500000
# 75%       50043.500000
# max      113812.000000
# Name: cases, dtype: float64

# %%
sns.set_style('whitegrid')
ny_nassau['cases'].hist(bins=10)
plt.xlabel('Cases')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')
